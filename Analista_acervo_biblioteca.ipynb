# %% [markdown]
# <a href="https://colab.research.google.com/github/al00pes/acervo_biblioteca/blob/main/Analista_acervo_biblioteca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importanto das bibliotecas necessárias
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from datetime import datetime

# %% [markdown]
# Importando os dados

# %%
df_2010_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv', delimiter=',')
df_2010_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv', delimiter=',')
df_2011_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv', delimiter=',')
df_2011_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv', delimiter=',')
df_2012_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv', delimiter=',')
df_2012_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv', delimiter=',')
df_2013_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv', delimiter=',')
df_2013_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv', delimiter=',')
df_2014_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv', delimiter=',')
df_2014_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv', delimiter=',')
df_2015_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv', delimiter=',')
df_2015_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv', delimiter=',')
df_2016_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv', delimiter=',')
df_2016_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv', delimiter=',')
df_2017_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv', delimiter=',')
df_2017_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv', delimiter=',')
df_2018_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv', delimiter=',')
df_2018_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv', delimiter=',')
df_2019_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv', delimiter=',')
df_2019_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv', delimiter=',')
df_2020_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv', delimiter=',')

# %%
#importando arquivo parquet

df_exemplares = pd.read_parquet('/content/dados_exemplares.parquet')
df_exemplares.head()
# Out:
#        id_exemplar codigo_barras            colecao  \
# index
# 0                5       L000003  Acervo Circulante
# 1                4       L000002  Acervo Circulante
# 2                3       L000001  Acervo Circulante
# 3                7       L000114  Acervo Circulante
# 5               10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#        registro_sistema
# index
# 0                     1
# 1                     1
# 2                     1
# 3                     5
# 5                    15

# %% [markdown]
# Contatenando os dataframes

# %%
df_acervo = pd.concat([df_2020_1,df_2010_2,df_2011_1,df_2011_2,df_2012_2,df_2013_1,df_2013_2,df_2014_1,
                       df_2014_2,df_2015_1,df_2015_2,df_2016_1,df_2016_2,df_2017_1,df_2017_2,df_2018_1,df_2018_2,
                       df_2019_1,df_2019_2,df_2020_1],ignore_index=True)

df_acervo.head(5)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0        2962509    2007005628                            NaN
# 1        2962510       L202802                            NaN
# 2        2962511    2012008328                            NaN
# 3        2962512    2012055016  2020/01/17 09:56:18.380000000
# 4        2962513       L197391  2020/01/17 23:50:18.862000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2020/01/02 08:17:30.290000000  2020/01/07 11:14:07.000000000
# 1  2020/01/02 08:17:30.391000000  2020/01/07 11:14:17.000000000
# 2  2020/01/02 08:17:30.436000000  2020/01/07 11:24:46.000000000
# 3  2020/01/02 08:36:40.163000000  2020/01/31 14:53:52.000000000
# 4  2020/01/02 09:36:03.877000000  2020/01/24 08:18:19.000000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.018103e+10  ALUNO DE PÓS-GRADUAÇÃO
# 1        2.018103e+10  ALUNO DE PÓS-GRADUAÇÃO
# 2        2.018103e+10  ALUNO DE PÓS-GRADUAÇÃO
# ...

# %% [markdown]
# Verificando linhas duplicadas

# %%
df_acervo.duplicated().sum()
# Out:
# 26580

# %% [markdown]
# Excluíndo as linha duplicadas

# %%
df_acervo_01 = df_acervo.drop_duplicates()

#Verificando se existe nulos
df_acervo_01.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Verificando valores nulos

# %%
df_acervo_01.isna().sum()
# Out:
# id_emprestimo                 0
# codigo_barras                 0
# data_renovacao          1156437
# data_emprestimo               0
# data_devolucao             6466
# matricula_ou_siape         2854
# tipo_vinculo_usuario          0
# dtype: int64

# %% [markdown]
# Excluíndo os dados nulos

# %%
df_acervo_02 = df_acervo_01.dropna()

#verificando se os nulos foram excluídos
df_acervo_02.isna().sum()
# Out:
# id_emprestimo           0
# codigo_barras           0
# data_renovacao          0
# data_emprestimo         0
# data_devolucao          0
# matricula_ou_siape      0
# tipo_vinculo_usuario    0
# dtype: int64

# %% [markdown]
# Verificando os tipo das colunas

# %%
df_acervo_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 869451 entries, 3 to 2030052
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id_emprestimo         869451 non-null  int64
#  1   codigo_barras         869451 non-null  object
#  2   data_renovacao        869451 non-null  object
#  3   data_emprestimo       869451 non-null  object
#  4   data_devolucao        869451 non-null  object
#  5   matricula_ou_siape    869451 non-null  float64
#  6   tipo_vinculo_usuario  869451 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 53.1+ MB

# %%
df_acervo_02.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 3        2962512    2012055016  2020/01/17 09:56:18.380000000
# 4        2962513       L197391  2020/01/17 23:50:18.862000000
# 5        2962514    2016030245  2020/01/17 23:50:18.835000000
# 6        2962515       L153495  2020/01/15 08:47:19.222000000
# 7        2962516    2008053151  2020/01/15 08:47:19.200000000
#
#                  data_emprestimo                 data_devolucao  \
# 3  2020/01/02 08:36:40.163000000  2020/01/31 14:53:52.000000000
# 4  2020/01/02 09:36:03.877000000  2020/01/24 08:18:19.000000000
# 5  2020/01/02 09:36:03.938000000  2020/01/24 08:18:13.000000000
# 6  2020/01/02 09:51:24.086000000  2020/01/28 12:00:15.000000000
# 7  2020/01/02 09:51:24.121000000  2020/01/28 12:00:22.000000000
#
#    matricula_ou_siape             tipo_vinculo_usuario
# 3        2.019015e+10               ALUNO DE GRADUAÇÃO
# 4        2.018005e+10               ALUNO DE GRADUAÇÃO
# ...

# %% [markdown]
# Transformando as colunas data_renovacao,data_emprestimo,data_devolucao no tipo datetime

# %%
df_acervo_02['data_devolucao'] = pd.to_datetime(df_acervo_02['data_devolucao'])
df_acervo_02['data_emprestimo'] = pd.to_datetime(df_acervo_02['data_emprestimo'])
df_acervo_02['data_renovacao'] = pd.to_datetime(df_acervo_02['data_renovacao'])

# %% [markdown]
# Extraindo somente a data das colunas

# %%
df_acervo_02['data_devolucao'] = df_acervo_02['data_devolucao'].dt.date
df_acervo_02['data_emprestimo'] = df_acervo_02['data_emprestimo'].dt.date
df_acervo_02['data_renovacao'] = df_acervo_02['data_renovacao'].dt.date

# %% [markdown]
# Transformando as colunas novamente no tipo date

# %%
df_acervo_02['data_devolucao'] = pd.to_datetime(df_acervo_02['data_devolucao'])
df_acervo_02['data_emprestimo'] = pd.to_datetime(df_acervo_02['data_emprestimo'])
df_acervo_02['data_renovacao'] = pd.to_datetime(df_acervo_02['data_renovacao'])
#exibindo as informações
df_acervo_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 869451 entries, 3 to 2030052
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id_emprestimo         869451 non-null  int64
#  1   codigo_barras         869451 non-null  object
#  2   data_renovacao        869451 non-null  datetime64[ns]
#  3   data_emprestimo       869451 non-null  datetime64[ns]
#  4   data_devolucao        869451 non-null  datetime64[ns]
#  5   matricula_ou_siape    869451 non-null  float64
#  6   tipo_vinculo_usuario  869451 non-null  object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(2)
# memory usage: 53.1+ MB

# %% [markdown]
# Transformando a coluna 'matricula_ou_siape' em integer

# %%
df_acervo_02['matricula_ou_siape'] = df_acervo_02['matricula_ou_siape'].astype(int)

#Exibindo a info
df_acervo_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 869451 entries, 3 to 2030052
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id_emprestimo         869451 non-null  int64
#  1   codigo_barras         869451 non-null  object
#  2   data_renovacao        869451 non-null  datetime64[ns]
#  3   data_emprestimo       869451 non-null  datetime64[ns]
#  4   data_devolucao        869451 non-null  datetime64[ns]
#  5   matricula_ou_siape    869451 non-null  int64
#  6   tipo_vinculo_usuario  869451 non-null  object
# dtypes: datetime64[ns](3), int64(2), object(2)
# memory usage: 53.1+ MB

# %% [markdown]
# Verificando quais são o tipos de vinculos dos usuário

# %%
df_acervo_02['tipo_vinculo_usuario'].unique()
# Out:
# array(['ALUNO DE GRADUAÇÃO', 'SERVIDOR TÉCNICO-ADMINISTRATIVO', 'DOCENTE',
#        'ALUNO DE PÓS-GRADUAÇÃO', 'ALUNO MÉDIO/TÉCNICO', 'DOCENTE EXTERNO'],
#       dtype=object)

# %% [markdown]
# # Concatenando os dois dataframe

# %%
#Concatendo o dataframe especificando a coluna em comum
df_acervo_full = pd.merge(df_acervo_02,df_exemplares,how='inner',on='codigo_barras')

df_acervo_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 818282 entries, 0 to 818281
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id_emprestimo         818282 non-null  int64
#  1   codigo_barras         818282 non-null  object
#  2   data_renovacao        818282 non-null  datetime64[ns]
#  3   data_emprestimo       818282 non-null  datetime64[ns]
#  4   data_devolucao        818282 non-null  datetime64[ns]
#  5   matricula_ou_siape    818282 non-null  int64
#  6   tipo_vinculo_usuario  818282 non-null  object
#  7   id_exemplar           818282 non-null  int64
#  8   colecao               818282 non-null  object
#  9   biblioteca            818282 non-null  object
#  10  status_material       818282 non-null  object
#  11  localizacao           818282 non-null  int64
#  12  registro_sistema      818282 non-null  int64
# dtypes: datetime64[ns](3), int64(5), object(5)
# ...

# %%
#Exibindo o dataframe

df_acervo_full.head()
# Out:
#    id_emprestimo codigo_barras data_renovacao data_emprestimo data_devolucao  \
# 0        2962512    2012055016     2020-01-17      2020-01-02     2020-01-31
# 1        1398767    2012055016     2013-01-07      2012-12-21     2013-01-11
# 2        1593205    2012055016     2013-09-30      2013-09-16     2013-12-13
# 3        1661338    2012055016     2014-01-23      2014-01-09     2014-01-28
# 4        1888722    2012055016     2014-12-15      2014-12-01     2015-01-05
#
#    matricula_ou_siape tipo_vinculo_usuario  id_exemplar            colecao  \
# 0         20190153535   ALUNO DE GRADUAÇÃO      1019380  Acervo Circulante
# 1          2011001903   ALUNO DE GRADUAÇÃO      1019380  Acervo Circulante
# 2          2012958543   ALUNO DE GRADUAÇÃO      1019380  Acervo Circulante
# 3          2011035527   ALUNO DE GRADUAÇÃO      1019380  Acervo Circulante
# 4          2012948251   ALUNO DE GRADUAÇÃO      1019380  Acervo Circulante
#
# ...

# %% [markdown]
# # Analise Exploratória

# %% [markdown]
# Questões a serem observadas com os dados :
#
# 1- A quantidade de empréstimos está aumentando ou diminuindo ao decorrer dos últimos anos?
#
# 2 - Em quais bibliotecas do sistema estão a maior quantidade de empréstimos?
#
# 3 -Quais são os temas mais emprestados? E os menos?

# %%
#1- A quantidade de empréstimos está aumentando ou diminuindo ao decorrer dos últimos anos?
df_data_emprestimo = df_acervo_full.set_index('data_emprestimo')

df_data_emprestimo.id_emprestimo.resample('Y').count()
# Out:
# data_emprestimo
# 2010-12-31     37555
# 2011-12-31     93768
# 2012-12-31     49566
# 2013-12-31    105416
# 2014-12-31     94177
# 2015-12-31     85409
# 2016-12-31     94921
# 2017-12-31     94080
# 2018-12-31     81853
# 2019-12-31     74149
# 2020-12-31      7388
# Freq: A-DEC, Name: id_emprestimo, dtype: int64

# %% [markdown]
# Após a análise, é possível observar uma diminuição dos emprestimos de livros apartir de 2018 e também podemos observar que o ano de 2013 foi o que periodo que mais houve emprestimo de livro.

# %% [markdown]
# Mostra que a quantidade de emprestimos a cada ano vem aumentando de forma significativa.

# %%
#2 - Em quais bibliotecas do sistema estão a maior quantidade de empréstimos?
df_acervo_full['biblioteca'].value_counts(ascending=True)
# Out:
# biblioteca
# Biblioteca Setorial do Núcleo de Ensino Superior do Agreste - NESA - Nova Cruz                 253
# Biblioteca Setorial Moacyr de Góes - CE                                                        262
# Biblioteca Setorial Árvore do Conhecimento - Instituto do Cérebro - ICe                        447
# Biblioteca Setorial do Núcleo de Educação da Infância - NEI                                    671
# Biblioteca Setorial Prof. Dr. Marcelo Bezerra de Melo Tinôco - DARQ - ­CT                      977
# Biblioteca Setorial Prof. Horácio Nicolas Solimo - ­ Engenharia Química - EQ - CT             1359
# Biblioteca Setorial Prof. Leopoldo Nelson - ­Centro de Biociências - CB                       3556
# Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA                               3668
# Biblioteca Setorial Pe. Jaime Diniz - Escola de Música - EMUFRN                               3965
# ...

# %% [markdown]
# AS 5 bibliotecas mais emprestaram livros:
#
# 1. Biblioteca Setorial da Faculdade de Ciências da Saúde do Trairi - FACISA - Santa Cruz: 20588 livro emprestado
#
# 2. Biblioteca Setorial Profª. Maria Lúcia da Costa Bezerra - ­CERES­ - Caicó: 22384 livro emprestado
#
# 3. Biblioteca Setorial Prof. Alberto Moreira Campos - ­Departamento de Odontologia: 23334 livro emprestado
#
# 4. Biblioteca Setorial do Centro Ciências da Saúde - CCS : 50566 livro emprestado
#
# 5. Biblioteca Central Zila Mamede: 612984 livro emprestado

# %%
#3 -Quais são os temas mais emprestados? E os menos?

df_acervo_full['colecao'].value_counts(ascending=True)
# Out:
# colecao
# Obras Raras                                   1
# Trabalho Acadêmico                            2
# Teses                                         3
# Literatura de Cordel                          6
# Coleção Zila Mamede                          13
# Necessidades Educacionais Específicas        13
# Eventos                                      15
# Coleção Mossoroense                          15
# Folhetos                                     30
# Dissertações                                 47
# Obras de Referência                          56
# Multimeios                                   59
# Publicações da UFRN                         192
# Publicações de Autores do RN                286
# Monografias                                 472
# Acervo Circulante                        817072
# Name: count, dtype: int64

# %% [markdown]
# As coleções Top 3 que mais foram emprestadas:
#
# *   Acervo Circulante
# *   Monografiass
# *   Publicações de Autores do RN
#
# e as coleções que menos foram emprestadas são:
#
# * Obras Raras
# * Trabalho Acadêmico
# * Literatura de Cordel
